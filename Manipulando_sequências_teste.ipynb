# %% [markdown]
# <a href="https://colab.research.google.com/github/queirozhanna/queirozhanna/blob/main/Manipulando_sequ%C3%AAncias_teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from Bio.Seq import Seq
seq1 = Seq("ACGTAGCTACGATCACAGCTA")
print("Minha sequência é", seq1)

rc = seq1.reverse_complement()
print("O reverso complementar é", rc)

rna = seq1.transcribe()
print("A sequência transcrita é", rna)

protein = seq1.translate()
print("A sequência da proteína é", protein)
# Out:
# Minha sequência é ACGTAGCTACGATCACAGCTA
# O reverso complementar é TAGCTGTGATCGTAGCTACGT
# A sequência transcrita é ACGUAGCUACGAUCACAGCUA
# A sequência da proteína é T*LRSQL

# %%
# Out:
# WARNING: The default download format has changed from PDB to PDBx/mmCif
# Structure exists: '/content/md/4mdp.cif'
# <Structure id=4mdp>
# <Model id=0>
# <Chain id=A>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-a3a485f8b1ee> in <module>
#      18
#      19     for residue in cadeia:
# ---> 20       nome = residuo.get_resname()
#      21       if nome != "HOH":
#      22         print(nome, residuo.id[1])
#
# NameError: name 'residuo' is not defined
